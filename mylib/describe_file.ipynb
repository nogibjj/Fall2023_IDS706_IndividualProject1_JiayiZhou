# %% [markdown]
# ### Individual Project
# #### Jiayi Zhou
# ##### This notebook read in a dataset by url. It provides summary statistics and visualizaiton plots for a data frame.

# %%
# import library
import lib

# %%
# read in dataset
data_read = lib.read_file(
    "https://raw.githubusercontent.com/fivethirtyeight/data/master/goose/goose_rawdata.csv"
)
data_read.head()
# Out:
#              name  year team league  goose_eggs  broken_eggs  mehs  \
# 0      Dolf Luque  1921  CIN     NL           3            1     0
# 1    Mike Kircher  1921  SLN     NL           0            1     0
# 2     Slim Sallee  1921  NY1     NL          13            6     2
# 3       Lou North  1921  SLN     NL          10            4     0
# 4  Dana Fillingim  1921  BSN     NL           4            1     1
#
#    league_average_gpct  ppf  replacement_gpct      gwar key_retro
# 0             0.752062   94          0.717062  0.068511  luqud101
# 1             0.749262   96          0.714262 -0.371416  kircm101
# 2             0.746462   98          0.711462 -0.269244  salls101
# 3             0.749262   96          0.714262  0.000173  nortl101
# 4             0.749262   96          0.714262  0.222919  filld101

# %%
# data summary for data frame
summary_data = lib.describe_file(data_read)
summary_data
# Out:
#                year    goose_eggs   broken_eggs          mehs  \
# count  30962.000000  30962.000000  30962.000000  30962.000000
# mean    1981.135650      5.529294      1.790679      1.494122
# std       25.718454      9.429182      2.643708      2.476357
# min     1921.000000      0.000000      0.000000      0.000000
# 25%     1962.000000      0.000000      0.000000      0.000000
# 50%     1986.000000      1.000000      1.000000      0.000000
# 75%     2003.000000      6.000000      2.000000      2.000000
# max     2017.000000     82.000000     22.000000     23.000000
#
#        league_average_gpct           ppf  replacement_gpct          gwar
# count         30962.000000  30962.000000      30962.000000  20929.000000
# mean              0.753962    100.281603          0.718962      0.198106
# std               0.022236      4.792580          0.022236      0.954528
# min               0.661454     88.000000          0.626454     -3.673632
# ...

# %%
# data visualization between variables
lib.plot_file(data_read)
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>
